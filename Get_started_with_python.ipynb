# %% [markdown]
# # **Get Started with Python**
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# **Integers and Float Data types**
#
# If a number does not contain decimal it is consider as integer whereas otherwise it is consider as float.
# Lets see some examples

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
y = 10.45
print(type(y))
# Out:
# <class 'float'>

# %% [markdown]
# **String Data type**
#
#
# > Sequence of characters is called strings. They are often represented by "  " or '   '.
# Let us see some examples

# %%
s = print("Hello")
# Out:
# Hello

# %% [markdown]
# If we need to type sentence
#
#
# >Let's learn python with Kitty
#
# The syntax will be

# %%
s = "Let's learn python with kitty"
print(s)
# Out:
# Let's learn python with kitty

# %% [markdown]
# If we need to type sentence
#
#
# >'Get started with python' is a "good" tutorial by Kitty
#
# The syntax will be

# %%
s = ''''Get started with python' is a "good" tutorial by Kitty'''
print(s)
# Out:
# 'Get started with python' is a "good" tutorial by Kitty

# %% [markdown]
# If we need to type sentence
#
#
# >'Get started with python'
#
# > is a
#
# > good tutorial by Kitty
#
#
#
#
#
#
#
#
# The syntax will be

# %%
s = """'Get started with python' 
is a
good tutorial by Kitty"""
print(s)
# Out:
# 'Get started with python'
# is a
# good tutorial by Kitty

# %% [markdown]
# **Boolean Data Type**
#
# Boolean data type in python only supports "True " or "False". *True* is internally represented as *1* whereas *False* is internally represented as *0*.
#
# Let's us understand with an examples

# %%
x = 10
y = 20
z = x > y

print(type(x))
print(type(y))
print(type(z))
print(z)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# False

# %% [markdown]
# **Arithmetic Operators and Integers**
#
# There are 7 arithmetic operators availble in python. These are the following :
#
#
# 1. Addition (+)
# 1. Subtraction (-)
# 2. Multiplication (*)
# 1. Divison  (/)
# 2.  Modulus (%)
# 1.  Integer division (//)
# 2.  Exponential (**)
#
# Let us see some examples of arithmetic operators !

# %%
print(10+2)
print(2.0+3)
print(13-98)
# Out:
# 12
# 5.0
# -85

# %% [markdown]
# *In the above examples we observe that when both the operands are integers/ float, then the result is also integer/ float. Whereas when one of the operators is float then the result is also float.*

# %%
print(10/2)
print(10.0/2)
# Out:
# 5.0
# 5.0

# %% [markdown]
# *For division operator, we observe that the result is always float invariable of the type of operand.*

# %%
print(15//4)
print(15//4.0)
# Out:
# 3
# 3.0

# %% [markdown]
# **Input function()**
#
# This is a user interactive function where the input is taken by the user. Let us see few examples to deploy this function.

# %%
x0 = input("get started with python is a good tutorial?")
print(x)

x1 = input("enter a value : ")
y1 = input ("enter a value :")
print(x1+y1)
print(type(x1))
print(type(y1))
# Out:
# get started with python is a good tutorial?yes
# 10
# enter a value : 4
# enter a value :3
# 43
# <class 'str'>
# <class 'str'>

# %% [markdown]
# *We observe that rather than addition operation, we got concatenation of values entered. This is because the data type of input is string. The required addition can be done by changing the data type using python inbuilt function, Let us see an example.*

# %%
x1 = input("enter a value : ")
y1 = input ("enter a value :")
print(int(x1)+int(y1))
print(type(x1))
print(type(y1))
# Out:
# enter a value : 4
# enter a value :3
# 7
# <class 'str'>
# <class 'str'>

# %% [markdown]
# *However, a more efficient approach would be to use **eval** **function** which implicitly convert the data into it data type.*

# %% [markdown]
# **Print function ()**
#
# Let us understand how print function can be deployed to show how to display your results.

# %%
print('Hello \n Python')
print('Hello \t Python')
print('Hello'+ 'Python')
print('Hello'*5)
# Out:
# Hello
#  Python
# Hello 	 Python
# HelloPython
# HelloHelloHelloHelloHello

# %% [markdown]
# **If, If-else and elif statement**
#
#
# There are three types of control statement in python :
#
# 1.   Sequential: Here, instruction are executed in the way they are written.
#
# 2.   Selection : Here, instruction are executed selectively, for example if, else-if and elif
# 1.   Iterative : Here, instruction are executed repeatedly, for example : while and for loops.

# %% [markdown]
# **Conditioning and Branching**
#
# Let's understand how if statement works pictorially.
#
# ![if else-1.png](data:image/png;base64,...)

# %% [markdown]
# Let us write a program to understand if-else statement elaborately,

# %%
n = eval(input("Rate Kitty's Tutorial: "))
print("Check if it's between 0 -10")
if (0<=n<=10):
  print("I rate Kitty's Tutorial:",n)
print("Thank You !")
# Out:
# Rate Kitty's Tutorial: 9
# Check if it's between 0 -10
# I rate Kitty's Tutorial: 9
# Thank You !

# %% [markdown]
# Let us understand how if-else condition statement works
#
# ![if else-2.png](data:image/png;base64,...)

# %% [markdown]
# Now to understand the if- else condition we will understand it with the help of code.

# %%
n = eval(input("Rate Kitty's Tutorial: "))
print("Thanks for the review")
if (0<=n<=10):
  print("I rate Kitty's Tutorial:",n)
else :
  print("Check if it's between 0 -10")
print("Thank You !")
# Out:
# Rate Kitty's Tutorial: 9
# Thanks for the review
# I rate Kitty's Tutorial: 9
# Thank You !

# %% [markdown]
# **Range()**
#
# The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number.
#
# Let us understand with few examples

# %%
x = range(5)
print(x)

x1 = range(0, 10,2) # the third argument is the set with whichthe sequene is incremented
print(x1)

x2 = range(10,0,-1)
print(x2)
# Out:
# range(0, 5)
# range(0, 10, 2)
# range(10, 0, -1)

# %% [markdown]
# **While Loop**
#
# Let us understand pictorially how while loop works
# ![if else-1 (1) (1).png](data:image/png;base64,...)

# %%
n = int(input("Pls enter a number : "))
print("You have entered",n)
i = 0 
while i<=n:
  print(i)
  i += 1
print("end of program")
# Out:
# Pls enter a number : 4
# You have entered 4
# 0
# 1
# 2
# 3
# 4
# end of program

# %% [markdown]
# **For Loop**

# %%
for i in "Hello":
  print(i)
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# Write a program using loop to print out odd numbers.

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# **Break and Continue Statements**
#
# In Python, break and continue statements can alter the flow of a normal loop.
#
# Loops iterate over a block of code until the test expression is false, but sometimes we wish to terminate the current iteration or even the whole loop without checking test expression.
#
# The break and continue statements are used in these cases.
#
# Let us see some examples.

# %%
l = [1,34,5,6,2,4,599,9,54]
n = int(input("Pls enter a value you need to search:"))
for i in l :
  print(n,i)
  if i == n:
    print("Found")
    break
# Out:
# Pls enter a value you need to search:599
# 599 1
# 599 34
# 599 5
# 599 6
# 599 2
# 599 4
# 599 599
# Found

# %% [markdown]
# Write a program to return all the odd numbers from the list.

# %%
l = [1,34,5,6,2,4,599,9,54]
for i in l:
  if i%2 ==0:
    continue
  print(i)
# Out:
# 1
# 5
# 599
# 9

# %% [markdown]
# List
#
#
#
# *   List are an ordered sequence of data.
# *   List are mutable
# *   List are created using elements separated by commas within square brackets.
# *   List can have elements of same type or mixed type
#
# Examples
# L = [23, "hello", 4.5]
#
# Let's learn some of the operations which can be done on a list.
#
# *Indexing started with 0*

# %%
#concatenation of list

L1 = [20, 'hello', 4.5]
L2 = ["python", 6,12.4]
L3 = L1 + L2
print(L3)
# Out:
# [20, 'hello', 4.5, 'python', 6, 12.4]

# %%
#Another method would be to use insert, append and extend
L1.insert(2,"python")
print(L1)
# Out:
# [20, 'hello', 'python', 4.5]

# %%
# append object to end
L1.append(40)
print(L1)
# Out:
# [20, 'hello', 'python', 4.5, 40]

# %%
L1.extend(["FUN"])
print(L1)
# Out:
# [20, 'hello', 'python', 4.5, 40, 'FUN']

# %%
#Slicing 
#get first three elements 
L1[0:3]
# Out:
# [20, 'hello', 'python']

# %%
#converting a string into list
my_statement = 'this is a good tutorial by kitty'
my_statement.split()
# Out:
# ['this', 'is', 'a', 'good', 'tutorial', 'by', 'kitty']

# %% [markdown]
# Dictionaries
#
#
#
# *   Dictionaries have keys and values.
# *  Dictionaries have keys instead of indices.
# *  Keys are immutable and unique
# *  Dictionaries are defined using curly brackets i.e { }
# *   Each key, value pair is separeted by commas.
#
# Example
#
# D = {'USA': 100, 'UK': 200,'INDIA':300}

# %%
D = {'USA': 100, 'UK': 200,'INDIA':300}
#add to dictionary
D['AUS']=400
print(D)
# Out:
# {'USA': 100, 'UK': 200, 'INDIA': 300, 'AUS': 400}

# %% [markdown]
# **Functions()**
#
# A function is a block of code which only runs when it is called.
# You can pass data, known as parameters, into a function.
# A function can return data as a result.
#
#
# Let us write a function and understand it better.

# %%
def add_num(a,b):
  return a+b

c = add_num(3,6)
print(c)
# Out:
# 9

# %%
#for adding variable numbers of arguments

def sum_num(*a):
  sum_it = 0
  for i in a:
    sum_it += i
  return sum_it

x = sum_num(4,3,4)
print(x)
# Out:
# 11

# %% [markdown]
# **Defining Classes and Creating Objects**
#
#
# A class is a user-defined blueprint or prototype from which objects are created. Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made. Each class instance can have attributes attached to it for maintaining its state. Class instances can also have methods (defined by its class) for modifying its state.
#
#
# Let us understand how to create class and object in the following code

# %%
class Tutorial():
  '''this is a class example'''
  def __init__(self,name,rate):
    self.name = name
    self.rate = rate
    Tutorial.author = 'Kitty'
  def __str__(self):
    'It was good learning with Kitty'
  def display(self):
    print("tutorial name :", self.name)
    print("tutorial rating :", self.rate)
    print("Author :", Tutorial.author)


T = [Tutorial('Get_started_with_python', 5), Tutorial('Get_started_with_deep_learning',5)]
for i in T:
  i.display()
# Out:
# tutorial name : Get_started_with_python
# tutorial rating : 5
# Author : Kitty
# tutorial name : Get_started_with_deep_learning
# tutorial rating : 5
# Author : Kitty
